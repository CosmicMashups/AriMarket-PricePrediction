# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import logging
import os
import time
import warnings

warnings.filterwarnings('ignore')

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

pd.set_option('display.max_rows', None)


def greedy_sarima(df, column, p_range=(25, 50), d_range=(0, 3), q_range=(25, 50), seasonal_range=(0, 2)):
    start_time = time.time()  # Start timing the function
    data = df[column].dropna()
    best_score, best_params = float('inf'), None

    # Search for best (p, d, q) parameters
    for p in range(*p_range):
        for q in range(*q_range):
            try:
                model = SARIMAX(data, order=(p, 0, q), seasonal_order=(0, 0, 0, 0)).fit(disp=False)
                predictions = model.fittedvalues
                mse = mean_squared_error(data[0:], predictions)
                if mse < best_score:
                    best_score, best_params = mse, (p, 0, q, 0, 0, 0)
            except Exception:
                continue

    best_p, best_d, best_q, _, _, _ = best_params
    # Search for best seasonal (P, D, Q, S) parameters
    for P in range(*seasonal_range):
        for Q in range(*seasonal_range):
            for S in [12]:  # Common seasonality period (e.g., monthly data with 12 periods)
                try:
                    model = SARIMAX(data, order=(best_p, best_d, best_q),
                                    seasonal_order=(P, 0, Q, S)).fit(disp=False)
                    predictions = model.fittedvalues
                    mse = mean_squared_error(data[best_d:], predictions[best_d:])
                    if mse < best_score:
                        best_score, best_params = mse, (best_p, best_d, best_q, P, 0, Q, S)
                except Exception:
                    continue

    end_time = time.time()
    logging.info(f"Best Parameters: {best_params} with MSE: {best_score}")
    logging.info(f"Runtime for greedy_sarima: {end_time - start_time:.2f} seconds")
    return best_params, best_score


def train_sarima_model(df, column, params):
    start_time = time.time()
    model = SARIMAX(df[column], order=params[:3], seasonal_order=params[3:]).fit(disp=False)
    end_time = time.time()
    logging.info(f"Runtime for train_sarima_model: {end_time - start_time:.2f} seconds")
    return model


def main():
    overall_start_time = time.time()

    for group_id, (group_name, commodities) in COMMODITY_GROUPS.items():
        logging.info(f"Processing commodity group: {group_name}")
        
        for commodity_id, (commodity_name, csv_path) in commodities.items():
            logging.info(f"Processing commodity: {commodity_name}")
            
            if not os.path.exists(csv_path):
                logging.error(f"File not found: {csv_path}")
                continue

            df = pd.read_csv(csv_path, index_col='Date', parse_dates=True)
            logging.info(f"Data loaded successfully for {commodity_name}.")

            for column in ["High", "Low"]:
                if column not in df.columns:
                    logging.warning(f"Column '{column}' not found in the dataset. Skipping analysis for this column.")
                    continue

                logging.info(f"Analyzing {column} prices for {commodity_name}.")
                params, mse = greedy_sarima(df, column)
                if params:
                    logging.info(f"Optimal parameters for {column} in {commodity_name}: {params} with MSE: {mse}")
                    model = train_sarima_model(df, column, params)
                else:
                    logging.warning(f"No valid parameters found for {column} in {commodity_name}.")

    overall_end_time = time.time()
    logging.info(f"Total runtime for the script: {overall_end_time - overall_start_time:.2f} seconds")


if __name__ == "__main__":    
    COMMODITY_GROUPS = {
        # 1: ("Rice", {
        #     1: ('Regular-Milled Rice', '../csv/rice/regular_milled_rice.csv'),
        #     2: ('Well-Milled Rice', '../csv/rice/well_milled_rice.csv'),
        #     3: ('Premium Rice', '../csv/rice/premium_rice.csv'),
        #     4: ('Special Rice', '../csv/rice/special_rice.csv'),
        # }),
        2: ("Meat", {
            1: ('Beef Brisket', '../csv/meat/beef_brisket.csv'),
            2: ('Beef Rump', '../csv/meat/beef_rump.csv'),
            3: ('Whole Chicken', '../csv/meat/whole_chicken.csv'),
            4: ('Pork Belly', '../csv/meat/pork_belly.csv'),
            5: ('Pork Ham', '../csv/meat/pork_kasim.csv'),
        }),
        3: ("Fish", {
            1: ('Alumahan', '../csv/fish/alumahan.csv'),
            2: ('Bangus', '../csv/fish/bangus.csv'),
            3: ('Galunggong', '../csv/fish/galunggong.csv'),
            4: ('Tilapia', '../csv/fish/tilapia.csv'),
        }),
        4: ("Fruits", {
            1: ('Banana (Lakatan)', '../csv/fruits/banana_lakatan.csv'),
            2: ('Calamansi', '../csv/fruits/calamansi.csv'),
            3: ('Mango', '../csv/fruits/mango.csv'),
            4: ('Papaya', '../csv/fruits/papaya.csv'),
        }),
        5: ("Vegetables", {
            1: ('Cabbage', '../csv/vegetables/cabbage.csv'),
            2: ('Carrots', '../csv/vegetables/carrots.csv'),
            3: ('Eggplant', '../csv/vegetables/eggplant.csv'),
            4: ('Tomato', '../csv/vegetables/tomato.csv'),
            5: ('Potato', '../csv/vegetables/white_potato.csv'),
        }),
        6: ("Spices", {
            1: ('Garlic', '../csv/spices/garlic.csv'),
            2: ('Red Onion', '../csv/spices/red_onion.csv'),
        })
    }
    
    main()

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import logging
import os
import time
import warnings

warnings.filterwarnings('ignore')

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

pd.set_option('display.max_rows', None)


def greedy_arima(df, column, p_range=(0, 28), d_range=(0, 3), q_range=(0, 28), test_size=0.2):
    start_time = time.time()  # Start timing the function
    data = df[column].dropna()

    # Train-test split
    train_data, test_data = train_test_split(data, test_size=test_size, shuffle=False)
    
    best_score, best_params = float('inf'), None

    # Grid search for best p, d, q
    for p in range(*p_range):
        try:
            model = ARIMA(train_data, order=(p, 0, 0)).fit()
            predictions = model.predict(start=len(train_data), end=len(train_data) + len(test_data) - 1)
            mse = mean_squared_error(test_data, predictions)
            if mse < best_score:
                best_score, best_params = mse, (p, 0, 0)
        except Exception:
            continue

    best_p, _, best_q = best_params
    for d in range(*d_range):
        try:
            model = ARIMA(train_data, order=(best_p, d, best_q)).fit()
            predictions = model.predict(start=len(train_data), end=len(train_data) + len(test_data) - 1)
            mse = mean_squared_error(test_data, predictions)
            if mse < best_score:
                best_score, best_params = mse, (best_p, d, best_q)
        except Exception:
            continue

    best_p, best_d, _ = best_params
    for q in range(*q_range):
        try:
            model = ARIMA(train_data, order=(best_p, best_d, q)).fit()
            predictions = model.predict(start=len(train_data), end=len(train_data) + len(test_data) - 1)
            mse = mean_squared_error(test_data, predictions)
            if mse < best_score:
                best_score, best_params = mse, (best_p, best_d, q)
        except Exception:
            continue

    end_time = time.time()
    logging.info(f"Best Parameters: {best_params} with MSE: {best_score}")
    logging.info(f"Runtime for greedy_arima: {end_time - start_time:.2f} seconds")
    return best_params, best_score


def train_arima_model(df, column, params):
    start_time = time.time()
    model = ARIMA(df[column], order=params).fit()
    end_time = time.time()
    logging.info(f"Runtime for train_arima_model: {end_time - start_time:.2f} seconds")
    return model


def main():
    overall_start_time = time.time()

    for group_id, (group_name, commodities) in COMMODITY_GROUPS.items():
        logging.info(f"Processing commodity group: {group_name}")
        
        for commodity_id, (commodity_name, csv_path) in commodities.items():
            logging.info(f"Processing commodity: {commodity_name}")
            
            if not os.path.exists(csv_path):
                logging.error(f"File not found: {csv_path}")
                continue

            df = pd.read_csv(csv_path, index_col='Date', parse_dates=True)
            logging.info(f"Data loaded successfully for {commodity_name}.")

            for column in ["High", "Low"]:
                if column not in df.columns:
                    logging.warning(f"Column '{column}' not found in the dataset. Skipping analysis for this column.")
                    continue

                logging.info(f"Analyzing {column} prices for {commodity_name}.")
                params, mse = greedy_arima(df, column)
                if params:
                    logging.info(f"Optimal parameters for {column} in {commodity_name}: {params} with MSE: {mse}")
                    model = train_arima_model(df, column, params)
                else:
                    logging.warning(f"No valid parameters found for {column} in {commodity_name}.")

    overall_end_time = time.time()
    logging.info(f"Total runtime for the script: {overall_end_time - overall_start_time:.2f} seconds")


if __name__ == "__main__":    
    COMMODITY_GROUPS = {
        # 1: ("Rice", {
        #     1: ('Regular-Milled Rice', '../csv/rice/regular_milled_rice.csv'),
        #     2: ('Well-Milled Rice', '../csv/rice/well_milled_rice.csv'),
        #     3: ('Premium Rice', '../csv/rice/premium_rice.csv'),
        #     4: ('Special Rice', '../csv/rice/special_rice.csv'),
        # }),
        # 2: ("Meat", {
            # 1: ('Beef Brisket', '../csv/meat/beef_brisket.csv'),
            # 2: ('Beef Rump', '../csv/meat/beef_rump.csv'),
            # 3: ('Whole Chicken', '../csv/meat/whole_chicken.csv'),
            # 4: ('Pork Belly', '../csv/meat/pork_belly.csv'),
            # 5: ('Pork Ham', '../csv/meat/pork_kasim.csv'),
        # }),
        3: ("Fish", {
            1: ('Alumahan', '../csv/fish/alumahan.csv'),
            2: ('Bangus', '../csv/fish/bangus.csv'),
            3: ('Galunggong', '../csv/fish/galunggong.csv'),
            4: ('Tilapia', '../csv/fish/tilapia.csv'),
        }),
        4: ("Fruits", {
            # 1: ('Banana (Lakatan)', '../csv/fruits/banana_lakatan.csv'),
            2: ('Calamansi', '../csv/fruits/calamansi.csv'),
            3: ('Mango', '../csv/fruits/mango.csv'),
            4: ('Papaya', '../csv/fruits/papaya.csv'),
        }),
        5: ("Vegetables", {
            1: ('Cabbage', '../csv/vegetables/cabbage.csv'),
            2: ('Carrots', '../csv/vegetables/carrots.csv'),
            3: ('Eggplant', '../csv/vegetables/eggplant.csv'),
            4: ('Tomato', '../csv/vegetables/tomato.csv'),
            5: ('Potato', '../csv/vegetables/white_potato.csv'),
        }),
        6: ("Spices", {
            1: ('Garlic', '../csv/spices/garlic.csv'),
            # 2: ('Red Onion', '../csv/spices/red_onion.csv'),
        })
    }
    
    main()
# Out:
# 2024-12-16 00:34:05,331 - Processing commodity group: Fish
# 2024-12-16 00:34:05,332 - Processing commodity: Bangus
# 2024-12-16 00:34:05,363 - Data loaded successfully for Bangus.
# 2024-12-16 00:34:05,363 - Analyzing High prices for Bangus.
# 2024-12-16 00:36:47,562 - Best Parameters: (16, 1, 13) with MSE: 97.46040012432361
# 2024-12-16 00:36:47,563 - Runtime for greedy_arima: 162.20 seconds
# 2024-12-16 00:36:47,570 - Optimal parameters for High in Bangus: (16, 1, 13) with MSE: 97.46040012432361
# 2024-12-16 00:36:51,275 - Runtime for train_arima_model: 3.70 seconds
# 2024-12-16 00:36:51,276 - Analyzing Low prices for Bangus.
# 2024-12-16 00:39:19,427 - Best Parameters: (14, 1, 20) with MSE: 120.47269309700394
# 2024-12-16 00:39:19,427 - Runtime for greedy_arima: 148.15 seconds
# 2024-12-16 00:39:19,435 - Optimal parameters for Low in Bangus: (14, 1, 20) with MSE: 120.47269309700394
# 2024-12-16 00:39:25,180 - Runtime for train_arima_model: 5.74 seconds
# 2024-12-16 00:39:25,182 - Processing commodity: Galunggong
# 2024-12-16 00:39:25,211 - Data loaded successfully for Galunggong.
# 2024-12-16 00:39:25,212 - Analyzing High prices for Galunggong.
# 2024-12-16 00:41:00,301 - Best Parameters: (3, 0, 2) with MSE: 2237.7197402775464
# 2024-12-16 00:41:00,302 - Runtime for greedy_arima: 95.09 seconds
# 2024-12-16 00:41:00,308 - Optimal parameters for High in Galunggong: (3, 0, 2) with MSE: 2237.7197402775464
# 2024-12-16 00:41:00,657 - Runtime for train_arima_model: 0.35 seconds
# 2024-12-16 00:41:00,660 - Analyzing Low prices for Galunggong.
# 2024-12-16 00:44:06,871 - Best Parameters: (16, 1, 6) with MSE: 555.92392748789
# 2024-12-16 00:44:06,872 - Runtime for greedy_arima: 186.21 seconds
# 2024-12-16 00:44:06,879 - Optimal parameters for Low in Galunggong: (16, 1, 6) with MSE: 555.92392748789
# 2024-12-16 00:44:09,206 - Runtime for train_arima_model: 2.33 seconds
# 2024-12-16 00:44:09,206 - Processing commodity: Tilapia
# 2024-12-16 00:44:09,233 - Data loaded successfully for Tilapia.
# 2024-12-16 00:44:09,234 - Analyzing High prices for Tilapia.
# 2024-12-16 00:45:12,869 - Best Parameters: (0, 0, 0) with MSE: 144.93217146459247
# 2024-12-16 00:45:12,870 - Runtime for greedy_arima: 63.63 seconds
# 2024-12-16 00:45:12,876 - Optimal parameters for High in Tilapia: (0, 0, 0) with MSE: 144.93217146459247
# 2024-12-16 00:45:12,923 - Runtime for train_arima_model: 0.04 seconds
# 2024-12-16 00:45:12,927 - Analyzing Low prices for Tilapia.
# 2024-12-16 00:47:48,610 - Best Parameters: (14, 1, 0) with MSE: 81.70204900473173
# 2024-12-16 00:47:48,610 - Runtime for greedy_arima: 155.68 seconds
# 2024-12-16 00:47:48,617 - Optimal parameters for Low in Tilapia: (14, 1, 0) with MSE: 81.70204900473173
# 2024-12-16 00:47:48,885 - Runtime for train_arima_model: 0.27 seconds
# 2024-12-16 00:47:48,886 - Processing commodity group: Fruits
# 2024-12-16 00:47:48,887 - Processing commodity: Banana (Lakatan)
# 2024-12-16 00:47:48,904 - Data loaded successfully for Banana (Lakatan).
# 2024-12-16 00:47:48,904 - Analyzing High prices for Banana (Lakatan).
# 2024-12-16 00:49:44,570 - Best Parameters: (7, 0, 10) with MSE: 30.404078593328038
# 2024-12-16 00:49:44,571 - Runtime for greedy_arima: 115.66 seconds
# 2024-12-16 00:49:44,577 - Optimal parameters for High in Banana (Lakatan): (7, 0, 10) with MSE: 30.404078593328038
# 2024-12-16 00:49:46,490 - Runtime for train_arima_model: 1.91 seconds
# 2024-12-16 00:49:46,493 - Analyzing Low prices for Banana (Lakatan).
# 2024-12-16 00:52:27,513 - Best Parameters: (15, 1, 17) with MSE: 12.55776035207705
# 2024-12-16 00:52:27,514 - Runtime for greedy_arima: 161.02 seconds
# 2024-12-16 00:52:27,520 - Optimal parameters for Low in Banana (Lakatan): (15, 1, 17) with MSE: 12.55776035207705
# 2024-12-16 00:52:32,696 - Runtime for train_arima_model: 5.17 seconds
# 2024-12-16 00:52:32,698 - Processing commodity: Calamansi
# 2024-12-16 00:52:32,724 - Data loaded successfully for Calamansi.
# 2024-12-16 00:52:32,725 - Analyzing High prices for Calamansi.
# 2024-12-16 00:54:35,914 - Best Parameters: (1, 0, 0) with MSE: 308.6166380393199
# 2024-12-16 00:54:35,914 - Runtime for greedy_arima: 123.19 seconds
# 2024-12-16 00:54:35,920 - Optimal parameters for High in Calamansi: (1, 0, 0) with MSE: 308.6166380393199
# 2024-12-16 00:54:35,979 - Runtime for train_arima_model: 0.06 seconds
# 2024-12-16 00:54:35,984 - Analyzing Low prices for Calamansi.
# 2024-12-16 00:58:41,858 - Best Parameters: (21, 0, 13) with MSE: 354.048829737208
# 2024-12-16 00:58:41,859 - Runtime for greedy_arima: 245.87 seconds
# 2024-12-16 00:58:41,865 - Optimal parameters for Low in Calamansi: (21, 0, 13) with MSE: 354.048829737208
# 2024-12-16 00:58:47,794 - Runtime for train_arima_model: 5.93 seconds
# 2024-12-16 00:58:47,795 - Processing commodity: Mango
# 2024-12-16 00:58:47,821 - Data loaded successfully for Mango.
# 2024-12-16 00:58:47,822 - Analyzing High prices for Mango.
# 2024-12-16 01:00:10,680 - Best Parameters: (0, 0, 3) with MSE: 12521.182141142004
# 2024-12-16 01:00:10,680 - Runtime for greedy_arima: 82.86 seconds
# 2024-12-16 01:00:10,687 - Optimal parameters for High in Mango: (0, 0, 3) with MSE: 12521.182141142004
# 2024-12-16 01:00:10,984 - Runtime for train_arima_model: 0.30 seconds
# 2024-12-16 01:00:10,988 - Analyzing Low prices for Mango.
# 2024-12-16 01:04:12,099 - Best Parameters: (24, 2, 1) with MSE: 4787.85635885078
# 2024-12-16 01:04:12,100 - Runtime for greedy_arima: 241.11 seconds
# 2024-12-16 01:04:12,106 - Optimal parameters for Low in Mango: (24, 2, 1) with MSE: 4787.85635885078
# 2024-12-16 01:04:16,320 - Runtime for train_arima_model: 4.21 seconds
# 2024-12-16 01:04:16,321 - Processing commodity: Papaya
# 2024-12-16 01:04:16,348 - Data loaded successfully for Papaya.
# 2024-12-16 01:04:16,349 - Analyzing High prices for Papaya.
# 2024-12-16 01:08:04,616 - Best Parameters: (24, 1, 14) with MSE: 173.66389418178667
# 2024-12-16 01:08:04,617 - Runtime for greedy_arima: 228.27 seconds
# 2024-12-16 01:08:04,622 - Optimal parameters for High in Papaya: (24, 1, 14) with MSE: 173.66389418178667
# 2024-12-16 01:08:12,231 - Runtime for train_arima_model: 7.61 seconds
# 2024-12-16 01:08:12,236 - Analyzing Low prices for Papaya.
# 2024-12-16 01:16:56,566 - Best Parameters: (26, 2, 27) with MSE: 51.08362358185692
# 2024-12-16 01:16:56,566 - Runtime for greedy_arima: 524.33 seconds
# 2024-12-16 01:16:56,574 - Optimal parameters for Low in Papaya: (26, 2, 27) with MSE: 51.08362358185692
# 2024-12-16 01:17:10,840 - Runtime for train_arima_model: 14.27 seconds
# 2024-12-16 01:17:10,844 - Processing commodity group: Vegetables
# 2024-12-16 01:17:10,844 - Processing commodity: Cabbage
# 2024-12-16 01:17:10,899 - Data loaded successfully for Cabbage.
# 2024-12-16 01:17:10,900 - Analyzing High prices for Cabbage.
# 2024-12-16 01:20:56,257 - Best Parameters: (24, 0, 24) with MSE: 453.454637985415
# 2024-12-16 01:20:56,258 - Runtime for greedy_arima: 225.36 seconds
# 2024-12-16 01:20:56,262 - Optimal parameters for High in Cabbage: (24, 0, 24) with MSE: 453.454637985415
# 2024-12-16 01:21:06,079 - Runtime for train_arima_model: 9.81 seconds
# 2024-12-16 01:21:06,088 - Analyzing Low prices for Cabbage.
# 2024-12-16 01:24:10,750 - Best Parameters: (19, 0, 24) with MSE: 400.5066893804049
# 2024-12-16 01:24:10,751 - Runtime for greedy_arima: 184.66 seconds
# 2024-12-16 01:24:10,757 - Optimal parameters for Low in Cabbage: (19, 0, 24) with MSE: 400.5066893804049
# 2024-12-16 01:24:20,403 - Runtime for train_arima_model: 9.64 seconds
# 2024-12-16 01:24:20,407 - Processing commodity: Carrots
# 2024-12-16 01:24:20,435 - Data loaded successfully for Carrots.
# 2024-12-16 01:24:20,435 - Analyzing High prices for Carrots.
# 2024-12-16 01:26:27,732 - Best Parameters: (7, 0, 1) with MSE: 1177.0769447508749
# 2024-12-16 01:26:27,733 - Runtime for greedy_arima: 127.30 seconds
# 2024-12-16 01:26:27,738 - Optimal parameters for High in Carrots: (7, 0, 1) with MSE: 1177.0769447508749
# 2024-12-16 01:26:28,208 - Runtime for train_arima_model: 0.47 seconds
# 2024-12-16 01:26:28,212 - Analyzing Low prices for Carrots.
# 2024-12-16 01:28:26,481 - Best Parameters: (1, 0, 0) with MSE: 956.2219638878837
# 2024-12-16 01:28:26,483 - Runtime for greedy_arima: 118.27 seconds
# 2024-12-16 01:28:26,489 - Optimal parameters for Low in Carrots: (1, 0, 0) with MSE: 956.2219638878837
# 2024-12-16 01:28:26,538 - Runtime for train_arima_model: 0.05 seconds
# 2024-12-16 01:28:26,540 - Processing commodity: Eggplant
# 2024-12-16 01:28:26,566 - Data loaded successfully for Eggplant.
# 2024-12-16 01:28:26,567 - Analyzing High prices for Eggplant.
# 2024-12-16 01:31:21,813 - Best Parameters: (17, 1, 24) with MSE: 1584.487733288552
# 2024-12-16 01:31:21,813 - Runtime for greedy_arima: 175.25 seconds
# 2024-12-16 01:31:21,820 - Optimal parameters for High in Eggplant: (17, 1, 24) with MSE: 1584.487733288552
# 2024-12-16 01:31:30,238 - Runtime for train_arima_model: 8.42 seconds
# 2024-12-16 01:31:30,239 - Analyzing Low prices for Eggplant.
# 2024-12-16 01:33:56,438 - Best Parameters: (4, 1, 3) with MSE: 1074.793210594575
# 2024-12-16 01:33:56,439 - Runtime for greedy_arima: 146.20 seconds
# 2024-12-16 01:33:56,444 - Optimal parameters for Low in Eggplant: (4, 1, 3) with MSE: 1074.793210594575
# 2024-12-16 01:33:56,780 - Runtime for train_arima_model: 0.34 seconds
# 2024-12-16 01:33:56,787 - Processing commodity: Tomato
# 2024-12-16 01:33:56,816 - Data loaded successfully for Tomato.
# 2024-12-16 01:33:56,818 - Analyzing High prices for Tomato.
# 2024-12-16 01:36:06,077 - Best Parameters: (0, 0, 15) with MSE: 3100.868629197498
# 2024-12-16 01:36:06,078 - Runtime for greedy_arima: 129.26 seconds
# 2024-12-16 01:36:06,083 - Optimal parameters for High in Tomato: (0, 0, 15) with MSE: 3100.868629197498
# 2024-12-16 01:36:07,545 - Runtime for train_arima_model: 1.46 seconds
# 2024-12-16 01:36:07,546 - Analyzing Low prices for Tomato.
# 2024-12-16 01:38:53,331 - Best Parameters: (14, 0, 1) with MSE: 1538.1398677255636
# 2024-12-16 01:38:53,332 - Runtime for greedy_arima: 165.79 seconds
# 2024-12-16 01:38:53,337 - Optimal parameters for Low in Tomato: (14, 0, 1) with MSE: 1538.1398677255636
# 2024-12-16 01:38:54,948 - Runtime for train_arima_model: 1.61 seconds
# 2024-12-16 01:38:54,950 - Processing commodity: Potato
# 2024-12-16 01:38:55,001 - Data loaded successfully for Potato.
# 2024-12-16 01:38:55,001 - Analyzing High prices for Potato.
# 2024-12-16 01:47:43,172 - Best Parameters: (27, 1, 2) with MSE: 242.45046673431926
# 2024-12-16 01:47:43,173 - Runtime for greedy_arima: 528.17 seconds
# 2024-12-16 01:47:43,179 - Optimal parameters for High in Potato: (27, 1, 2) with MSE: 242.45046673431926
# 2024-12-16 01:47:49,236 - Runtime for train_arima_model: 6.06 seconds
# 2024-12-16 01:47:49,238 - Analyzing Low prices for Potato.
# 2024-12-16 01:49:40,508 - Best Parameters: (5, 1, 9) with MSE: 374.9254802433614
# 2024-12-16 01:49:40,508 - Runtime for greedy_arima: 111.27 seconds
# 2024-12-16 01:49:40,514 - Optimal parameters for Low in Potato: (5, 1, 9) with MSE: 374.9254802433614
# 2024-12-16 01:49:41,888 - Runtime for train_arima_model: 1.37 seconds
# 2024-12-16 01:49:41,894 - Processing commodity group: Spices
# 2024-12-16 01:49:41,895 - Processing commodity: Garlic
# 2024-12-16 01:49:41,949 - Data loaded successfully for Garlic.
# 2024-12-16 01:49:41,949 - Analyzing High prices for Garlic.
# 2024-12-16 01:52:02,048 - Best Parameters: (12, 1, 14) with MSE: 4016.2769333455617
# 2024-12-16 01:52:02,049 - Runtime for greedy_arima: 140.10 seconds
# 2024-12-16 01:52:02,054 - Optimal parameters for High in Garlic: (12, 1, 14) with MSE: 4016.2769333455617
# 2024-12-16 01:52:04,857 - Runtime for train_arima_model: 2.80 seconds
# 2024-12-16 01:52:04,860 - Analyzing Low prices for Garlic.
# 2024-12-16 01:54:43,145 - Best Parameters: (15, 0, 5) with MSE: 1162.2320757817058
# 2024-12-16 01:54:43,146 - Runtime for greedy_arima: 158.28 seconds
# 2024-12-16 01:54:43,151 - Optimal parameters for Low in Garlic: (15, 0, 5) with MSE: 1162.2320757817058
# 2024-12-16 01:54:45,745 - Runtime for train_arima_model: 2.59 seconds
# 2024-12-16 01:54:45,746 - Processing commodity: Red Onion
# 2024-12-16 01:54:45,799 - Data loaded successfully for Red Onion.
# 2024-12-16 01:54:45,799 - Analyzing High prices for Red Onion.
# 2024-12-16 01:56:57,647 - Best Parameters: (1, 1, 27) with MSE: 22.762687412595845
# 2024-12-16 01:56:57,648 - Runtime for greedy_arima: 131.85 seconds
# 2024-12-16 01:56:57,654 - Optimal parameters for High in Red Onion: (1, 1, 27) with MSE: 22.762687412595845
# 2024-12-16 01:57:06,265 - Runtime for train_arima_model: 8.61 seconds
# 2024-12-16 01:57:06,268 - Analyzing Low prices for Red Onion.
# 2024-12-16 01:59:45,798 - Best Parameters: (5, 1, 11) with MSE: 27.250144617666923
# 2024-12-16 01:59:45,800 - Runtime for greedy_arima: 159.53 seconds
# 2024-12-16 01:59:45,803 - Optimal parameters for Low in Red Onion: (5, 1, 11) with MSE: 27.250144617666923
# 2024-12-16 01:59:47,435 - Runtime for train_arima_model: 1.63 seconds
# 2024-12-16 01:59:47,439 - Total runtime for the script: 5142.11 seconds
